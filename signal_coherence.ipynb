# %% [markdown]
# Derived from https://matplotlib.org/stable/gallery/lines_bars_and_markers/cohere.html with slight modifications
#
# # Plotting the coherence of two signals
# An example showing how to plot the coherence of two signals using `cohere`

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# !python --version
print(f'Matplotlib version: {mpl.__version__}')
print(f'Numpy versiion: {np.__version__}')
# Out:
# Python 3.8.18
# Matplotlib version: 3.7.2
# Numpy versiion: 1.24.3

# %%
np.random.seed(19680801)

dt = 0.01
t = np.arange(0,10,dt)
n1 = np.random.randn(t.shape[0])
n2 = np.random.randn(t.shape[0])
y1 = np.sin(t * 100) + n1
y2 = np.sin(t * 100) + n2

fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(t, y1)
axs[0].plot(t, y2)
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(y1, y2, 256, 1. / dt)
axs[1].set_ylabel('Coherence')

plt.show()
