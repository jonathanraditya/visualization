# %% [markdown]
# Derived from https://matplotlib.org/stable/gallery/lines_bars_and_markers/categorical_variables.html with slight modifications
#
# # Plotting categorical variables
# You can pass categorical values (i.e. strings) directly as x- or y-values to many plotting functions

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# !python --version
print(f'Matplotlib version: {mpl.__version__}')
print(f'Numpy version: {np.__version__}')
# Out:
# Python 3.8.18
# Matplotlib version: 3.7.2
# Numpy version: 1.24.3

# %%
data = dict(apple=10, orange=15, lemon=5, lime=20)
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9,3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')

plt.show()

# %% [markdown]
# This works on both axes:

# %%
c = (1,0,1,1,0,1)
d = (0,0,0,0,1,1)
x = np.arange(len(c))
xl = ('combing', 'drinking', 'feeding', 'napping', 'playing', 'washing')
yl = ('happy', 'bored')

fig, ax = plt.subplots()
ax.plot(x, c, label='cat', color='tab:orange')
ax.plot(x, d, label='dog', color='tab:blue')
ax.set_yticks(np.unique(np.concatenate((c, d))), yl)
ax.set_xticks(x, xl)

ax.legend()

plt.show()

# %%
np.concatenate((c, d))
# Out:
# array([1, 0, 1, 1, 0, 1, 0, 0, 0, 0, 1, 1])
