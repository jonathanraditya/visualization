# %% [markdown]
# Derived from https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html with some modifications

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# !python --version
print(f'Matplotlib version: {mpl.__version__}')
print(f'Numpy version: {np.__version__}')
# Out:
# Python 3.8.18
# Matplotlib version: 3.7.2
# Numpy version: 1.24.3

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

species = ('Adelie', 'Chinstrap', 'Gentoo')
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))
w = 0.25
fig, ax = plt.subplots(layout='constrained')

for i, (k, v) in enumerate(penguin_means.items()):
    c = ax.bar(x + (w * i), v, w, label=k)
    ax.bar_label(c, padding=5)

ax.set(title='Penguin attributes by species', ylabel='Length (mm)', ylim=(0,250))
ax.set_xticks(x+w, species)
ax.legend(loc='upper left', ncols=3)
